# %%
import moabb
from moabb.datasets import BNCI2014_001
import mne
import matplotlib.pyplot as plt
# %matplotlib qt

# %%
dataset = BNCI2014_001()
subjects= [1]

# %%
sessions = dataset.get_data(subjects=subjects)

# %%
subject = 1
session_name = '0train'
run_name = '0'
raw = sessions[subject][session_name][run_name]

# %%
print(sessions[subject].keys())
# Out:
# dict_keys(['0train', '1test'])

# %%
event_id = dict(left=1, right=2, feet=3, tongue=4)

# %%
events = mne.find_events(raw, stim_channel="stim")
# Out:
# 48 events found on stim channel stim
# Event IDs: [1 2 3 4]

# %%
raw.plot(events=events, event_id=event_id)
# Out:
# <MNEBrowseFigure size 3840x2004 with 4 Axes>
